# %% [markdown]
# # Simple Improved Reference Subtraction (SIRS)<br> Compute $\alpha$ and $\beta$ for JWST NIRISS and SIRS Correct Files
#
# Bernard J. Rauscher<br>
# NASA Goddard Space Flight Center
#
# This example shows how to compute the frequency dependent weight vectors for JWST NIRISS. We use the resulting SIRS calibration file to SIRS correct an independent set of files.

# %%
# Standard Julia packages
using Revise
using Glob
using FITSIO

# The SIRS package
using SIRS

# %% [markdown]
# The NIRISS filenames do not sort nicely. Write a little utility function to sort lists of files by the integration timestamp.

# %%
"""
    sort_fits(files)

Sort a list of NIRISS files by integration start time

    Parameters: files::Vector{String}
                  A list of filenames
"""
function sort_fits(files)
   
    # Get timestamps for all files
    ts = ["",]
    for file in files
        f = FITS(file, "r")
        push!(ts, read_header(f[1])["DATE-OBS"]*"T"*read_header(f[1])["TIME-OBS"]) 
    end
    ts = ts[2:end]
    
    # Indirect sort
    return(files[sortperm(ts)])
end;

# %% [markdown]
# Use the files recommended by Chris Willott. Treat the first 24 as the training data. SIRS correct the last 24.

# %%
files = sort_fits(glob("*.fits", "/local/data/racy1/brausche/JWST/NIRISS/SIRS_Darks_Willott"));

# %%
naxis3 = 100; # Number of up-the-ramp frames from one of the FITS headers

# %%
# Instantiate a SIRSCore
#   * JWST uses 4 outputs
#   * Assume 12 pixel time overhead at the end of every row. This might not be correct
#   * JWST uses 10 µs per pixel dwell time
sc = SIRSCore("h2rg", 4, 12, 1.e-5, naxis3);

# %%
# Compute SIRS sums
clear!(sc) # Preemptively clear SIRScore. Sometimes I run this cell more than once.
for file in files[1:24]
    
    # Show some status
    println("Processing file: ", file)
   
    # Read some data
    f = FITS(file, "r")
    D = Float64.(read(f[1]))
    close(f)
    
    # Coadd
    coadd!(sc, D)

end
# Out:
# Processing file: /local/data/racy1/brausche/JWST/NIRISS/SIRS_Darks_Willott/NISNIRISSDARK-160051229_1_496_SE_2016-01-05T12h52m28.fits
# Processing file: /local/data/racy1/brausche/JWST/NIRISS/SIRS_Darks_Willott/NISNIRISSDARK-160051229_2_496_SE_2016-01-05T13h12m18.fits
# Processing file: /local/data/racy1/brausche/JWST/NIRISS/SIRS_Darks_Willott/NISNIRISSDARK-160051229_3_496_SE_2016-01-05T13h30m36.fits
# Processing file: /local/data/racy1/brausche/JWST/NIRISS/SIRS_Darks_Willott/NISNIRISSDARK-160051229_4_496_SE_2016-01-05T13h48m59.fits
# Processing file: /local/data/racy1/brausche/JWST/NIRISS/SIRS_Darks_Willott/NISNIRISSDARK-160051229_5_496_SE_2016-01-05T14h08m35.fits
# Processing file: /local/data/racy1/brausche/JWST/NIRISS/SIRS_Darks_Willott/NISNIRISSDARK-160051229_6_496_SE_2016-01-05T14h26m28.fits
# Processing file: /local/data/racy1/brausche/JWST/NIRISS/SIRS_Darks_Willott/NISNIRISSDARK-160051229_7_496_SE_2016-01-05T14h45m18.fits
# Processing file: /local/data/racy1/brausche/JWST/NIRISS/SIRS_Darks_Willott/NISNIRISSDARK-160051229_8_496_SE_2016-01-05T15h03m48.fits
# Processing file: /local/data/racy1/brausche/JWST/NIRISS/SIRS_Darks_Willott/NISNIRISSDARK-160051229_9_496_SE_2016-01-05T15h23m42.fits
# Processing file: /local/data/racy1/brausche/JWST/NIRISS/SIRS_Darks_Willott/NISNIRISSDARK-160051229_10_496_SE_2016-01-05T15h42m12.fits
# Processing file: /local/data/racy1/brausche/JWST/NIRISS/SIRS_Darks_Willott/NISNIRISSDARK-160051229_11_496_SE_2016-01-05T16h00m43.fits
# Processing file: /local/data/racy1/brausche/JWST/NIRISS/SIRS_Darks_Willott/NISNIRISSDARK-160051229_12_496_SE_2016-01-05T16h19m12.fits
# Processing file: /local/data/racy1/brausche/JWST/NIRISS/SIRS_Darks_Willott/NISNIRISSDARK-160051229_13_496_SE_2016-01-05T16h38m53.fits
# Processing file: /local/data/racy1/brausche/JWST/NIRISS/SIRS_Darks_Willott/NISNIRISSDARK-160051229_14_496_SE_2016-01-05T16h56m53.fits
# Processing file: /local/data/racy1/brausche/JWST/NIRISS/SIRS_Darks_Willott/NISNIRISSDARK-160051229_15_496_SE_2016-01-05T17h15m33.fits
# Processing file: /local/data/racy1/brausche/JWST/NIRISS/SIRS_Darks_Willott/NISNIRISSDARK-160051229_16_496_SE_2016-01-05T17h35m43.fits
# Processing file: /local/data/racy1/brausche/JWST/NIRISS/SIRS_Darks_Willott/NISNIRISSDARK-160051229_17_496_SE_2016-01-05T17h53m33.fits
# Processing file: /local/data/racy1/brausche/JWST/NIRISS/SIRS_Darks_Willott/NISNIRISSDARK-160051229_18_496_SE_2016-01-05T18h11m44.fits
# Processing file: /local/data/racy1/brausche/JWST/NIRISS/SIRS_Darks_Willott/NISNIRISSDARK-160051229_19_496_SE_2016-01-05T18h31m07.fits
# Processing file: /local/data/racy1/brausche/JWST/NIRISS/SIRS_Darks_Willott/NISNIRISSDARK-160051229_20_496_SE_2016-01-05T18h50m16.fits
# Processing file: /local/data/racy1/brausche/JWST/NIRISS/SIRS_Darks_Willott/NISNIRISSDARK-160051229_21_496_SE_2016-01-05T19h08m06.fits
# Processing file: /local/data/racy1/brausche/JWST/NIRISS/SIRS_Darks_Willott/NISNIRISSDARK-160051229_22_496_SE_2016-01-05T19h26m49.fits
# Processing file: /local/data/racy1/brausche/JWST/NIRISS/SIRS_Darks_Willott/NISNIRISSDARK-160051229_23_496_SE_2016-01-05T19h47m09.fits
# Processing file: /local/data/racy1/brausche/JWST/NIRISS/SIRS_Darks_Willott/NISNIRISSDARK-160051229_24_496_SE_2016-01-05T20h04m55.fits

# %%
# Solve for weights
solve!(sc);

# %%
# Save results
SIRS.save(sc, ENV["HOME"] * "/tmp/" * "20160105_niriss_sirs_first-24b.jld")

# %%
wplot(sc, 1, nice=false)

# %%
f = FITS(files[25], "r")
D = Float64.(read(f[1]))
D2 = copy(D)
close(f);

# %%
sirssub!(sc, D)
sirssub!(sc, D2, rowsonly=true)

# %%
Λ = LegendreMatrices((naxis3,2));

# %%
f = FITS(ENV["HOME"]*"/tmp/sirs.fits", "w")
write(f, legfit(Λ, D)[:,:,2])
close(f)

# %%
f = FITS(ENV["HOME"]*"/tmp/rows.fits", "w")
write(f, legfit(Λ, D2)[:,:,2])
close(f)
