# %% [markdown]
# # Reducing the Correlated Noise of JPL PPL Data using SIRS
#
# Bernard.J.Rauscher@nasa.gov<br>
# 20 April 2021
#
# ## 1. Introduction
#
# Roman data from the JPL Precision Projector Lab (PPL) have some correlated noise. The purpose of this notebook is to see if SIRS can reduce it. This notebook is in Julia 1.5.3. There exists a python back-end that can be used to apply its results to FITS files using python-3. To keep it simple, we're just working with Julia until we know that SIRS helps.
#
# In this notebook, we compute the SIRS frequency dependent weights. This is the time consuming part. The python-3 notebook 20210420_sirs_ppl.ipynb completes the demonstration by applying he weights that are computed here to the data.
#
# Note that the type of some cells is set to "Raw". This is done to prevent those cells from executing. To execute them, change the type to "Code".

# %%
# Standard imports
using Revise        # Handy for interactive work
using Glob          # Filename globbing
using FITSIO        # Julia's standard FITS package
using Jacobi        # Legendre polynomials defined here
using LinearAlgebra # Moore-Penrose inverse is here
using OMEinsum      # Tensor operations
using StatsBase     # Robuts statistics
using Plots         # Plotting

# Simple Improved Reference Subtraction (SIRS)
using SIRS
# Out:
# ┌ Info: Precompiling SIRS [40ae95f3-0455-409b-a0fb-071cca222575]
# └ @ Base loading.jl:1278

# %%
# The data are here on ADAPT
ddir = "/att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15"

# Put the results here
rdir = "/att/gpfsfs/briskfs01/ppl/brausche/roman_caldir/JPL_PPL_Results/";

# %%
# Get a list of the input files
files = glob("*.fits", ddir);

# %%
# Instantiate a SIRSCore. From looking at the FITS headers, I know that
# all files have 60 frames sampled up-the-ramp.
#
# According to Chaz Shapiro, the new row overhead (nroh)
# is different from in DCL data. According to Chaz, it is 26.48 µs.
# SIRS assumes that it is an integral number of pixel readout times.
# We will see how that imprints today. For now, say nroh = 5 pixels.
sc = SIRSCore(58, nroh=5); # Discard 1st two frames!

# %%
# Solve for the frequency dependent weights.
#
# This cell can be very time consuming. The execution time on
# Prism with 40 cores enabled is about 65 seconds/file.

for file in files
    
    # Show some status
    println("Processing file: ", file)
   
    # These are JPL PPL data. The format is a single datacube.
    # Like in the DCL, charge seems to integrate down. For now,
    # just leave this. 
    f = FITS(file, "r")
    D = Float64.(read(f[1]))
    close(f)
    
    # Consider dropping frame #1 before coadd. Chaz says that the
    # system is unstable.
    #
    # * First saved run on 4/19 kept 1st frame
    # * Second saved run on 4/19 discards it and the second,
    #   Which I found was often being thrown out.
    D = D[:,:,3:end]
    
    # Coadd
    coadd!(sc, D)

end
# Out:
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0000.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0001.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0002.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0003.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0004.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0005.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0006.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0007.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0008.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0009.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0010.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0011.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0012.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0013.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0014.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0015.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0016.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0017.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0018.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0019.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0020.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0021.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0022.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0023.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0024.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0025.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0026.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0027.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0028.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0029.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0030.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0031.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0032.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0033.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0034.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0035.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0036.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0037.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0038.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0039.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0040.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0041.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0042.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0043.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0044.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0045.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0046.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0047.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0048.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0049.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0050.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0051.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0052.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0053.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0054.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0055.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0056.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0057.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0058.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0059.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0060.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0061.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0062.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0063.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0064.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0065.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0066.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0067.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0068.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0069.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0070.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0071.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0072.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0073.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0074.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0075.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0076.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0077.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0078.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0079.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0080.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0081.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0082.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0083.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0084.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0085.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0086.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0087.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0088.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0089.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0090.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0091.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0092.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0093.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0094.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0095.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0096.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0097.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0098.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0099.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0100.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0101.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0102.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0103.fits
# Processing file: /att/gpfsfs/briskfs01/ppl/cshapiro/JPL-PPL/H4RG-18241/2021-04-15/PPL_longdark_0104.fits

# %%
# Solve for the frequency dependent weights, alpha and beta
solve!(sc);

# %%
# Save results
SIRS.save(sc, output_directory=rdir)

# %%
# sc = restore(rdir*"2021-04-21T06:57:06_PPL_18241_95.0K_-1.0V_SIRS.jld");

# %%
op1 = wplot(sc, 31, mag=1.5)
